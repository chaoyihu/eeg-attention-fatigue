# %%
from mne import io
from sklearn.utils import shuffle
import scipy.signal
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

def filt_coef(order, cutoff, filt_type, sampleRate):
    Nq = sampleRate//2
    Wn = cutoff / Nq
    b, a = scipy.signal.butter(order, Wn, filt_type)
    return b, a

# %% [markdown]
# # Data3

# %%
ls = os.listdir(r"..\data\data3_attention\raw")
newls = []
for fname in ls:
    if fname.endswith('11.edf'):
        newls.append(fname)
    if fname.endswith('12.edf'):
        newls.append(fname)
    if fname.endswith('13.edf'):
        newls.append(fname)

# %%
print(len(newls))
newls
# Out:
# 48
# ['0002_11.edf',
#  '0002_12.edf',
#  '0002_13.edf',
#  '0004_11.edf',
#  '0004_12.edf',
#  '0004_13.edf',
#  '0005_11.edf',
#  '0005_12.edf',
#  '0005_13.edf',
#  '0006_11.edf',
#  '0006_12.edf',
#  '0006_13.edf',
#  '0007_11.edf',
#  '0007_12.edf',
#  '0007_13.edf',
#  '0009_11.edf',
#  '0009_12.edf',
#  '0009_13.edf',
#  '0013_11.edf',
#  '0013_12.edf',
#  '0013_13.edf',
#  '0201_11.edf',
#  '0201_12.edf',
#  '0201_13.edf',
#  '0401_11.edf',
#  '0401_12.edf',
#  '0401_13.edf',
#  '0502_11.edf',
#  '0502_12.edf',
#  '0502_13.edf',
#  '0601_11.edf',
#  '0601_12.edf',
#  '0601_13.edf',
#  '0701_11.edf',
#  '0701_12.edf',
#  '0701_13.edf',
#  '0801_11.edf',
#  '0801_12.edf',
#  '0801_13.edf',
#  '0901_11.edf',
#  '0901_12.edf',
#  '0901_13.edf',
#  '1101_11.edf',
#  '1101_12.edf',
#  '1101_13.edf',
#  '1301_11.edf',
#  '1301_12.edf',
#  '1301_13.edf']

# %%
s = set()
for k in newls:
    s.add(k[0:4])
print(len(s))
# Out:
# 16

# %%
################# Multiple subjects #########################
window_length = 1000
datacuts = []
labels = []
threshold = 100
sampleRate = 1000

b, a = filt_coef(2, 30, 'lowpass', sampleRate)
d, c = filt_coef(5, 1, 'highpass', sampleRate)

for fname in newls:
    
    plt.figure(figsize=(16,6))
    
    fpath = os.path.join(r"..\data\data3_attention\raw", fname)
    r = io.read_raw_edf(fpath)
    unfilter_datacut = r.load_data()[['Fp1','Fp2']][0]
    unfilter_datacut = np.array(unfilter_datacut)
    
    print(unfilter_datacut.shape)
    
    ax1 = plt.subplot(311)
    ax1.set_title("data")
    for ch in range(2):
        plt.title(fname)
        plt.plot(unfilter_datacut[ch])      
    
    unfilter_datacut[0] = scipy.signal.filtfilt(b, a, unfilter_datacut[0])
    unfilter_datacut[1] = scipy.signal.filtfilt(b, a, unfilter_datacut[1])
    unfilter_datacut[0] = scipy.signal.filtfilt(d, c, unfilter_datacut[0])
    unfilter_datacut[1] = scipy.signal.filtfilt(d, c, unfilter_datacut[1])
    
    ax2 = plt.subplot(312)
    ax2.set_title("filtered data")
    for ch in range(2):
        plt.plot(unfilter_datacut[ch])
        
    unfilter_datacut = np.transpose(unfilter_datacut)
    print(unfilter_datacut.shape)
    datacut = []
    for i,j in unfilter_datacut:
        if abs(i) <= threshold and abs(j) <= threshold:
            datacut.append([i,j])
    datacut = np.transpose(np.array(datacut))
    print("===========",fname,"=============")
    print("datacut:", datacut.shape)

    
    datacut[0] = datacut[0] - min(datacut[0])
    datacut[1] = datacut[1] - min(datacut[1])
    scale = 2 * threshold
    datacut[0] = datacut[0] / scale
    datacut[1] = datacut[1] / scale

    
    ax3 = plt.subplot(313)
    ax3.set_title("scaled data")
    for ch in range(2):
        plt.plot(datacut[ch])
        
    st = sorted(datacut[0].copy())
    ax3 = plt.subplot(313)
    ax3.set_title("scaled data")
    plt.plot(st)
    plt.xlim([0,600000])
    plt.ylim([-2000,1000])
    upperthreshold = st[int(len(data[0]) * 0.95)]
    plt.axhline(y=upperthreshold,color='k')
    plt.text(0, upperthreshold, "threshold:"+str(upperthreshold))

    lowerthreshold = st[int(len(data[0]) * 0.05)]
    plt.axhline(y=lowerthreshold,color='k')
    plt.text(0, lowerthreshold, "threshold:"+str(lowerthreshold))
        
#     datacut = datacut[:, ::2]
    
#     savepath = os.path.join(r"..\data\data3_attention\raw_filtered_baselineSubtracted_thres_fp1fp2_500Hz\raw_filtered_baselineSubtracted_thres_resampled500Hz_fp1fp2_"+ fname.split('.')[0]+'.csv')
#     pd.DataFrame({'FP1':datacut[0], 'FP2':datacut[1]}).to_csv(savepath)

#     l = datacut.shape[1] # data points
#     n = int(l / window_length) # number of cuts

#     # Triple classification: L/M/H
#     label = int(fname.split(".")[0][-1]) - 1    # 0,1,2
#     for start in [i * window_length for i in list(range(n))]:
# #         label = int(fname.split('_')[-2][1]) - 1
#         arr = datacut[:, start: start + window_length]
#         datacuts.append(arr)
#         labels.append(label)

#     print(len(datacuts))
# Out:
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0601_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0601_13.edf =============
# datacut: (2, 541272)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0701_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0701_11.edf =============
# datacut: (2, 517101)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0701_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0701_12.edf =============
# datacut: (2, 526636)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0701_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0701_13.edf =============
# datacut: (2, 527040)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0801_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0801_11.edf =============
# datacut: (2, 530607)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0801_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0801_12.edf =============
# datacut: (2, 544048)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0801_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0801_13.edf =============
# datacut: (2, 552174)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0901_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0901_11.edf =============
# datacut: (2, 557983)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0901_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0901_12.edf =============
# datacut: (2, 558000)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\0901_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 0901_13.edf =============
# datacut: (2, 558000)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1101_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1101_11.edf =============
# datacut: (2, 554891)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1101_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1101_12.edf =============
# datacut: (2, 557960)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1101_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1101_13.edf =============
# datacut: (2, 556918)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1301_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1301_11.edf =============
# datacut: (2, 553413)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1301_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1301_12.edf =============
# datacut: (2, 558000)
# Extracting EDF parameters from D:\GitHub\EEG_fatigue\data\data3_attention\raw\1301_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 557999  =      0.000 ...   557.999 secs...
# (2, 558000)
# (558000, 2)
# =========== 1301_13.edf =============
# datacut: (2, 558000)
